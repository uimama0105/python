# %% [markdown]
# # chap6 檔案處理
# -os套件:用來處理目錄與文件，以及檔案的讀寫

# %%
import os
os.getcwd()  #回傳目前的工作目錄
# Out:
# '/content'

# %%
os.listdir(".")  #列出目錄下所有檔案
# Out:
# ['.config', 'sample_data']

# %%
os.makedirs("test")  #新增test目錄
os.listdir(".")
# Out:
# ['.config', 'test', 'sample_data']

# %%
os.rmdir("test")  #移除test目錄
os.listdir(".")
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# ###檔案處理
# -os套件有自己處理檔案的函式open
#
# -python也有自己處裡檔案的函式open(比較常用)
#
# -w = 可寫(預設建立檔案) 若檔案存在則會清除舊檔案
#
# -w+ = 可寫可讀(預設建立檔案) 若檔案存在則會清除舊檔案
#
# -r = 可讀
#
# -r+ = 可寫可讀 但寫入資料指向開頭
#
# -a = 可寫不能讀 寫入資料指向尾端
#
# -a+ = 可寫可讀 寫入資料指向尾端
#
# -b = 轉為2進位文件
#
# -ab+ = 2進位文件的讀寫 寫入資料指向尾端

# %%
#新增檔案
a=open("a.txt","w")
a.write("This is line 1")
a.write("This is line 2\n")
a.write("This is line 3\n")
a.close()

# %%
os.path.isfile("a.txt")
# Out:
# True

# %%
a=open("a.txt","r")
print(a.readlines())
a.close()
# Out:
# ['This is line 1This is line 2\n', 'This is line 3\n']

# %%
 if os.path.isfile("a.txt"):
   a=open("a.txt","r")
   print(a.readlines())
   a.close()
 else:
   print("檔案不存在")
# Out:
# ['This is line 1This is line 2\n', 'This is line 3\n']

# %% [markdown]
# #附加檔案

# %%
a=open("a,txt","a")  #參數"a"會把寫入資訊附加在檔案尾巴
a.write("This is line 4\n")
a.close()

# %%
a=open("a,txt","r")
print(a.readlines())
a.close()

# %%
a=open("a.txt","r+")  #參數"r+"會把寫入資訊附加在檔案開頭
a.write("This is line 5\n")
a.close()
